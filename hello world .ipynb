# %% [markdown]
# <a href="https://colab.research.google.com/github/thecodingbot1122/8051-all-codes/blob/main/hello%20world%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hellow world")
# Out:
# hellow world
